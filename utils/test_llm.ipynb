# %% [markdown]
# # LLM Training Data Contamination Check
#
# **Goal:** To investigate whether specific examples from the test set of a dataset (e.g., PolitiFact, GossipCop) might have been included in the training data of a given Large Language Model (LLM).
#
# **Methodology:**
# 1. Load the target dataset and select a few examples from the **test split**.
# 2. Load the LLM to be tested.
# 3. Query the LLM about these specific examples using:
#     *   **Direct Questioning:** Ask if the model has seen the exact text before.
#     *   **Completion Task:** Provide a prefix of the text and ask the model to complete it.
# 4. Analyze the responses. Verbatim completions or overly specific acknowledgments *might* suggest prior exposure, but are not definitive proof.
#
# **Disclaimer:** This method provides indicative evidence, not absolute proof. LLMs might generate text that coincidentally matches or claim knowledge they don't possess.

# %%
# Imports
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, set_seed
from datasets import load_dataset
import random
import textwrap

# Set a seed for reproducibility of example selection
set_seed(42)

# %% [markdown]
# ## 1. Configuration
# Specify the dataset name and the Hugging Face model ID you want to test.

# %%
# --- Configuration ---
DATASET_NAME = "politifact" # or "gossipcop"

# Select the model you want to test (choose one)
# MODEL_HF_ID = "meta-llama/Meta-Llama-3-8B-Instruct"
MODEL_HF_ID = "google/gemma-7b-it"
# MODEL_HF_ID = "mistralai/Mistral-7B-Instruct-v0.2"

NUM_EXAMPLES_TO_TEST = 20 # How many examples to pull from the test set
MAX_NEW_TOKENS_COMPLETION = 150 # Max tokens for the completion task
MAX_NEW_TOKENS_QUESTION = 75   # Max tokens for the direct question task
MAX_PREFIX_LENGTH = 100 # Number of words for the completion prefix

# Determine device and dtype (similar to prompt_hf_llm.py)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

TORCH_DTYPE = torch.float32
if DEVICE == "cuda":
    TORCH_DTYPE = torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16

print(f"Dataset to check: {DATASET_NAME}")
print(f"Model to test: {MODEL_HF_ID}")
print(f"Using device: {DEVICE}")
print(f"Using dtype: {TORCH_DTYPE}")
# Out:
# Dataset to check: politifact
# Model to test: google/gemma-7b-it
# Using device: cuda
# Using dtype: torch.bfloat16

# %% [markdown]
# ## 2. Load Dataset and Select Examples
# Load the specified dataset and randomly select a few examples from the test split.

# %%
# Load dataset
# Construct the dataset name as used in prompt_hf_llm.py
dataset_full_name = f"LittleFish-Coder/Fake_News_{DATASET_NAME}"

print(f"Loading dataset: {dataset_full_name}...")
try:
    # Use the same cache directory as other scripts
    dataset = load_dataset(dataset_full_name, cache_dir="../dataset")
    test_data = dataset['test']
    print(f"Dataset loaded successfully. Test split size: {len(test_data)}")
except Exception as e:
    print(f"Error loading dataset {dataset_full_name}: {e}")
    raise

# Select random examples from the test set
if len(test_data) < NUM_EXAMPLES_TO_TEST:
    print(f"Warning: Requested {NUM_EXAMPLES_TO_TEST} examples, but test set only has {len(test_data)}. Using all.")
    selected_indices = list(range(len(test_data)))
else:
    selected_indices = random.sample(range(len(test_data)), NUM_EXAMPLES_TO_TEST)

selected_examples = [test_data[i] for i in selected_indices]

print(f"\nSelected {len(selected_examples)} examples to test:")
for i, example in enumerate(selected_examples):
    # Display only the beginning of the text for brevity
    short_text = textwrap.shorten(example['text'], width=100, placeholder="...")
    print(f"  Example {i+1} (Index {selected_indices[i]}): Label={example['label']}, Text='{short_text}'")
# Out:
# Loading dataset: LittleFish-Coder/Fake_News_politifact...
# Dataset loaded successfully. Test split size: 102
#
# Selected 20 examples to test:
#   Example 1 (Index 81): Label=1, Text='Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday...'
#   Example 2 (Index 14): Label=1, Text='Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our...'
#   Example 3 (Index 3): Label=0, Text='Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that...'
#   Example 4 (Index 94): Label=0, Text='Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。 次の動画'
#   Example 5 (Index 35): Label=0, Text='Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the...'
#   Example 6 (Index 31): Label=0, Text='Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give...'
#   Example 7 (Index 28): Label=1, Text='Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. :...'
#   Example 8 (Index 17): Label=0, Text='Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on...'
#   Example 9 (Index 13): Label=0, Text='Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I...'
#   Example 10 (Index 86): Label=0, Text='Percent change from preceding period 17.76 KB View/Download File Why the extra step? This page...'
#   Example 11 (Index 69): Label=0, Text='Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his...'
#   Example 12 (Index 11): Label=0, Text='Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul Rumors are...'
#   Example 13 (Index 75): Label=0, Text='Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama...'
#   Example 14 (Index 54): Label=1, Text='Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him...'
#   Example 15 (Index 4): Label=0, Text='President Trump in Moon Township, Pennsylvania March 10, 2018 2018-03-10T22:31:03-05:00...'
#   Example 16 (Index 27): Label=1, Text='U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton...'
#   Example 17 (Index 29): Label=0, Text='Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to...'
#   Example 18 (Index 64): Label=1, Text='Who is affected by the government shutdown? Thousands of government workers are unsure whether or...'
#   Example 19 (Index 77): Label=0, Text='Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in...'
#   Example 20 (Index 71): Label=0, Text='Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s...'
# Dataset loaded successfully. Test split size: 102
#
# Selected 20 examples to test:
#   Example 1 (Index 81): Label=1, Text='Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday...'
#   Example 2 (Index 14): Label=1, Text='Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our...'
#   Example 3 (Index 3): Label=0, Text='Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that...'
#   Example 4 (Index 94): Label=0, Text='Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。 次の動画'
#   Example 5 (Index 35): Label=0, Text='Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the...'
#   Example 6 (Index 31): Label=0, Text='Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give...'
#   Example 7 (Index 28): Label=1, Text='Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. :...'
#   Example 8 (Index 17): Label=0, Text='Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on...'
#   Example 9 (Index 13): Label=0, Text='Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I...'
#   Example 10 (Index 86): Label=0, Text='Percent change from preceding period 17.76 KB View/Download File Why the extra step? This page...'
#   Example 11 (Index 69): Label=0, Text='Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his...'
#   Example 12 (Index 11): Label=0, Text='Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul Rumors are...'
#   Example 13 (Index 75): Label=0, Text='Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama...'
#   Example 14 (Index 54): Label=1, Text='Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him...'
#   Example 15 (Index 4): Label=0, Text='President Trump in Moon Township, Pennsylvania March 10, 2018 2018-03-10T22:31:03-05:00...'
#   Example 16 (Index 27): Label=1, Text='U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton...'
#   Example 17 (Index 29): Label=0, Text='Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to...'
#   Example 18 (Index 64): Label=1, Text='Who is affected by the government shutdown? Thousands of government workers are unsure whether or...'
#   Example 19 (Index 77): Label=0, Text='Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in...'
#   Example 20 (Index 71): Label=0, Text='Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s...'

# %% [markdown]
# ## 3. Load Model and Tokenizer
# Load the specified Hugging Face model and its corresponding tokenizer.

# %%
print(f"Loading tokenizer for {MODEL_HF_ID}...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_HF_ID, trust_remote_code=True)

# Set padding token if necessary (as in prompt_hf_llm.py)
if tokenizer.pad_token is None:
    if tokenizer.eos_token:
        tokenizer.pad_token = tokenizer.eos_token
        print(f"Set pad_token to eos_token: '{tokenizer.pad_token}'")
    else:
        tokenizer.add_special_tokens({'pad_token': '[PAD]'})
        print("Added '[PAD]' as pad_token.")
        # Note: If a pad token was added, the model might need resizing, but we'll handle that during pipeline creation if needed.

print(f"Loading model {MODEL_HF_ID} with dtype {TORCH_DTYPE} and device_map='auto'...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_HF_ID,
    torch_dtype=TORCH_DTYPE,
    trust_remote_code=True,
    device_map="auto" # Automatically distribute across available GPUs/CPU
)

# Resize model embeddings if a new pad token was added to the tokenizer
if tokenizer.pad_token == '[PAD]' and len(tokenizer) > model.config.vocab_size:
    model.resize_token_embeddings(len(tokenizer))
    print("Resized model token embeddings.")

print("Model and tokenizer loaded.")
try:
    if hasattr(model, 'hf_device_map'):
        print(f"Model device map: {model.hf_device_map}")
    elif hasattr(model, 'device'):
        print(f"Model loaded on device: {model.device}")
except Exception:
    print("Could not determine specific model device allocation.")
# Out:
# Loading tokenizer for google/gemma-7b-it...
# Loading model google/gemma-7b-it with dtype torch.bfloat16 and device_map='auto'...
# Loading model google/gemma-7b-it with dtype torch.bfloat16 and device_map='auto'...
# Loading checkpoint shards: 100%|██████████| 4/4 [00:06<00:00,  1.57s/it]
# Model and tokenizer loaded.
# Model device map: {'': 0}

# %% [markdown]
# ## 4. Create Text Generation Pipeline
# Set up the Hugging Face pipeline for text generation.

# %%
print("Creating text generation pipeline...")
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # We'll set max_new_tokens per task
    do_sample=False, # Use greedy decoding for consistency
    pad_token_id=tokenizer.pad_token_id,
    temperature=None,
    top_p=None,
    top_k=None
)
print(f"Pipeline created. Device: {generator.device}")
# Out:
# Creating text generation pipeline...
# Pipeline created. Device: cuda:0

# %% [markdown]
# ## 5. Define Contamination Check Functions
# Functions to perform the direct questioning and completion tasks.

# %%
def check_direct_question(example_text):
    """Asks the model if it has seen the text before."""
    prompt = f"I will provide you with a text snippet. Please tell me honestly if you have encountered this *exact* text during your training. Do not summarize or analyze it, just answer yes or no regarding prior exposure.\n\nText Snippet:\n'''\n{example_text}\n'''\n\nHave you seen this exact text before? Answer only yes or no."

    # Use model-specific chat templating if available
    try:
        messages = [{"role": "user", "content": prompt}]
        formatted_prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    except:
        # Fallback for models without chat templates
        formatted_prompt = prompt

    response = generator(formatted_prompt, max_new_tokens=MAX_NEW_TOKENS_QUESTION, return_full_text=False)
    return response[0]['generated_text'].strip()

def check_completion(example_text):
    """Asks the model to complete a prefix of the text."""
    words = example_text.split()
    if len(words) <= MAX_PREFIX_LENGTH:
        prefix = example_text # Use full text if shorter than prefix length
    else:
        prefix = " ".join(words[:MAX_PREFIX_LENGTH])

    prompt = f"Complete the following text:\n\n{prefix}"

    # Use model-specific chat templating if available (though less critical for completion)
    try:
        messages = [{"role": "user", "content": prompt}]
        formatted_prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
        # Remove potential trailing spaces/newlines added by template before the generation starts
        formatted_prompt = formatted_prompt.rstrip()
    except:
        formatted_prompt = prompt

    response = generator(formatted_prompt, max_new_tokens=MAX_NEW_TOKENS_COMPLETION, return_full_text=False)
    completion = response[0]['generated_text'].strip()

    # Check if the completion *exactly* matches the next part of the original text
    original_continuation = " ".join(words[MAX_PREFIX_LENGTH:])
    is_exact_match = False
    if completion and original_continuation.startswith(completion):
        is_exact_match = True

    return completion, is_exact_match, prefix

print("Contamination check functions defined.")
# Out:
# Contamination check functions defined.

# %% [markdown]
# ## 6. Run Checks on Selected Examples
# Iterate through the selected test examples and perform both checks.

# %%
results = []
print(f"\n--- Running Contamination Checks on {len(selected_examples)} Examples ---")

for i, example in enumerate(selected_examples):
    print(f"\n--- Checking Example {i+1} (Index {selected_indices[i]}) ---")
    example_text = example['text']
    print(f"Original Text (first 200 chars): {example_text[:200]}...")

    # 1. Direct Question
    print("\nRunning Direct Question Check...")
    try:
        direct_answer = check_direct_question(example_text)
        print(f"  Model's answer to 'Have you seen this text?': {direct_answer}")
    except Exception as e:
        print(f"  Error during direct question check: {e}")
        direct_answer = "Error"

    # 2. Completion Task
    print("\nRunning Completion Check...")
    try:
        completion, is_exact, prefix_used = check_completion(example_text)
        print(f"  Prefix Used ({len(prefix_used.split())} words): {prefix_used[:150]}...")
        print(f"  Model's Completion: {completion}")
        print(f"  Is Completion an Exact Match of Original Text?: {is_exact}")
    except Exception as e:
        print(f"  Error during completion check: {e}")
        completion, is_exact, prefix_used = "Error", False, "Error"

    results.append({
        "index": selected_indices[i],
        "text_start": example_text[:200] + "...",
        "direct_answer": direct_answer,
        "prefix_used": prefix_used,
        "completion": completion,
        "exact_match": is_exact
    })

print("\n--- Contamination Checks Complete ---")
# Out:
# --- Running Contamination Checks on 20 Examples ---
#
# --- Checking Example 1 (Index 81) ---
# Original Text (first 200 chars): Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday dismissed arguments that his father, Donald Trump Donald John TrumpOnly one way with Huawei — don't let it c...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text snippet you provided is not the exact text I have seen during my training.
#
# Running Completion Check...
#   Prefix Used (100 words): Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday dismissed arguments that his father, Donald Trump Donald J...
#   Model's Completion: Sure, here is the completed text:
#
# Eric Trump: It would be "foolish" for my dad to release tax returns
#
# Eric Trump on Wednesday dismissed arguments that his father, Donald Trump, should release his tax returns, saying doing so would be "foolish."
#
# "You would have a bunch of people who know nothing about taxes trying to look through and trying to come up with assumptions on things they know nothing about," Eric Trump said.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 2 (Index 14) ---
# Original Text (first 200 chars): Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our President, God Bless Him And His Supporters.” Do You Support To Tina ? – American President Donald J. Tru...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday dismissed arguments that his father, Donald Trump Donald J...
#   Model's Completion: Sure, here is the completed text:
#
# Eric Trump: It would be "foolish" for my dad to release tax returns
#
# Eric Trump on Wednesday dismissed arguments that his father, Donald Trump, should release his tax returns, saying doing so would be "foolish."
#
# "You would have a bunch of people who know nothing about taxes trying to look through and trying to come up with assumptions on things they know nothing about," Eric Trump said.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 2 (Index 14) ---
# Original Text (first 200 chars): Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our President, God Bless Him And His Supporters.” Do You Support To Tina ? – American President Donald J. Tru...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes. I have encountered this exact text snippet before. The text is similar to other political campaign text messages and has been seen in the wild.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes. I have encountered this exact text snippet before. The text is similar to other political campaign text messages and has been seen in the wild.
#
# Running Completion Check...
#   Prefix Used (60 words): Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our President, God Bless Him And His Supporters.” Do You Su...
#   Model's Completion: I am unable to complete the text as the text is politically biased and endorses a particular political figure. I am not able to provide content that endorses or takes a stance on political matters.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 3 (Index 3) ---
# Original Text (first 200 chars): Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets and club warehouse stores, to notify their...
#
# Running Direct Question Check...
#   Prefix Used (60 words): Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our President, God Bless Him And His Supporters.” Do You Su...
#   Model's Completion: I am unable to complete the text as the text is politically biased and endorses a particular political figure. I am not able to provide content that endorses or takes a stance on political matters.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 3 (Index 3) ---
# Original Text (first 200 chars): Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets and club warehouse stores, to notify their...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is exactly the same as the text I have seen during my training.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is exactly the same as the text I have seen during my training.
#
# Running Completion Check...
#   Prefix Used (74 words): Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, super...
#   Model's Completion: Sure, here is the completed text:
#
# Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets and club warehouse stores, to notify their customers with information regarding the source of certain foods. Food products covered by the law include muscle cut and ground meats: lamb, goat, and chicken; wild and farm-raised fish and shellfish; fresh and frozen fruits and vegetables; peanuts, pecans, and macadamia nuts; and ginseng.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 4 (Index 94) ---
# Original Text (first 200 chars): Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。
#
# 次の動画...
#
# Running Direct Question Check...
#   Prefix Used (74 words): Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, super...
#   Model's Completion: Sure, here is the completed text:
#
# Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets and club warehouse stores, to notify their customers with information regarding the source of certain foods. Food products covered by the law include muscle cut and ground meats: lamb, goat, and chicken; wild and farm-raised fish and shellfish; fresh and frozen fruits and vegetables; peanuts, pecans, and macadamia nuts; and ginseng.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 4 (Index 94) ---
# Original Text (first 200 chars): Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。
#
# 次の動画...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No. I have not seen this exact text before. The text snippet is in Japanese and I am not able to understand or process languages other than English.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No. I have not seen this exact text before. The text snippet is in Japanese and I am not able to understand or process languages other than English.
#
# Running Completion Check...
#   Prefix Used (11 words): Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。
#
# 次の動画...
#   Model's Completion: Sure, here is the completed text:
#
# Sen. Barack Obama's answer to meeting energy demands, if made effective, will result in related videos being automatically played.
#
# The following video:
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 5 (Index 35) ---
# Original Text (first 200 chars): Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the left threatens to derail what could be the biggest progressive achievement in half a century. It's the vi...
#
# Running Direct Question Check...
#   Prefix Used (11 words): Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。
#
# 次の動画...
#   Model's Completion: Sure, here is the completed text:
#
# Sen. Barack Obama's answer to meeting energy demands, if made effective, will result in related videos being automatically played.
#
# The following video:
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 5 (Index 35) ---
# Original Text (first 200 chars): Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the left threatens to derail what could be the biggest progressive achievement in half a century. It's the vi...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is exactly the same as the text in the article "Why the Public Option Isn't the Only Answer to Health-Care Reform" by Matt Miller.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is exactly the same as the text in the article "Why the Public Option Isn't the Only Answer to Health-Care Reform" by Matt Miller.
#
# Running Completion Check...
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   Prefix Used (100 words): Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the left threatens to derail what could be the biggest prog...
#   Model's Completion: Sure, here is the completed text:
#
# Why the Public Option Isn't the Only Answer to Health-Care Reform. A dangerous sentiment on the left threatens to derail what could be the biggest progressive achievement in half a century. It's the view that any health-care reform that doesn't include a public option isn't "real" reform and thus isn't worth doing. This mantra has become an article of faith among many Democrats who haven't necessarily thought through the matter but who take their cues from leaders advancing this argument. Unless liberals rethink this premise, and fast, Democrats will squander their best chance in a generation to end the scandal.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 6 (Index 31) ---
# Original Text (first 200 chars): Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of a protest organized by the Alliance Defense Fund, ...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have seen before.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have seen before.
#
# Running Completion Check...
#   Prefix Used (100 words): Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of ...
#   Model's Completion: Sure, here is the completed text:
#
# Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of a protest organized by the Alliance Defense Fund, a conservative legal-advocacy group. The protest will challenge an Internal Revenue Code restriction that limits the political activities of charitable organizations – including churches and other religious groups – that are exempt from taxation. According to the Internal Revenue Code, religious groups may lose their tax-exempt status if they officially endorse a political candidate. The ADF says that if its protest leads the Internal Revenue Service to reconsider the rule, the organization will be "pleased" and will "cease and desist" its protest.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 7 (Index 28) ---
# Original Text (first 200 chars): Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online
#
# **The conspiracy subreddit is a thinking ground. Above all else, we respect eve...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of ...
#   Model's Completion: Sure, here is the completed text:
#
# Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of a protest organized by the Alliance Defense Fund, a conservative legal-advocacy group. The protest will challenge an Internal Revenue Code restriction that limits the political activities of charitable organizations – including churches and other religious groups – that are exempt from taxation. According to the Internal Revenue Code, religious groups may lose their tax-exempt status if they officially endorse a political candidate. The ADF says that if its protest leads the Internal Revenue Service to reconsider the rule, the organization will be "pleased" and will "cease and desist" its protest.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 7 (Index 28) ---
# Original Text (first 200 chars): Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online
#
# **The conspiracy subreddit is a thinking ground. Above all else, we respect eve...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No. I have not seen this exact text before. The text you provided is not in my training data.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No. I have not seen this exact text before. The text you provided is not in my training data.
#
# Running Completion Check...
#   Prefix Used (92 words): Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online
#
# **The conspiracy subreddit is...
#   Model's Completion: The text you provided has been completed below:
#
# Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online
#
# The conspiracy subreddit is a thinking ground. Above all else, we respect everyone's opinions and **ALL** religious beliefs and creeds. We hope to challenge issues which have captured the public’s imagination, from JFK and UFOs to 9/11. This is a forum for free thinking, not hate speech. Respect other views and opinions, and keep an open mind. **Our intentions are aimed towards a fairer, more transparent world and a better future for everyone.**
#
# However, the text does not provide information about the text
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 8 (Index 17) ---
# Original Text (first 200 chars): Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort Hood psychiatrist Nidal Malik Hasan, an...
#
# Running Direct Question Check...
#   Prefix Used (92 words): Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online
#
# **The conspiracy subreddit is...
#   Model's Completion: The text you provided has been completed below:
#
# Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online
#
# The conspiracy subreddit is a thinking ground. Above all else, we respect everyone's opinions and **ALL** religious beliefs and creeds. We hope to challenge issues which have captured the public’s imagination, from JFK and UFOs to 9/11. This is a forum for free thinking, not hate speech. Respect other views and opinions, and keep an open mind. **Our intentions are aimed towards a fairer, more transparent world and a better future for everyone.**
#
# However, the text does not provide information about the text
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 8 (Index 17) ---
# Original Text (first 200 chars): Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort Hood psychiatrist Nidal Malik Hasan, an...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have seen before.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have seen before.
#
# Running Completion Check...
#   Prefix Used (100 words): Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew ...
#   Model's Completion: The text is complete as follows:
#
# Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort Hood psychiatrist Nidal Malik Hasan, an Army major who authorities say killed 13 people and wounded 30 others. "There is a chance our government knew all about this guy Hasan and did nothing because nobody wanted to be called an Islamaphobe," Hannity said. "Now, this is a terrorist act," Hannity said. "What does that say about Barack Obama and our government?" "Here's the point," Hannity said, "
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 9 (Index 13) ---
# Original Text (first 200 chars): Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a century since Theodore Roosevelt first called fo...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew ...
#   Model's Completion: The text is complete as follows:
#
# Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort Hood psychiatrist Nidal Malik Hasan, an Army major who authorities say killed 13 people and wounded 30 others. "There is a chance our government knew all about this guy Hasan and did nothing because nobody wanted to be called an Islamaphobe," Hannity said. "Now, this is a terrorist act," Hannity said. "What does that say about Barack Obama and our government?" "Here's the point," Hannity said, "
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 9 (Index 13) ---
# Original Text (first 200 chars): Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a century since Theodore Roosevelt first called fo...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# This text is the text of a speech by Barack Obama on healthcare reform in 2009.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# This text is the text of a speech by Barack Obama on healthcare reform in 2009.
#
# Running Completion Check...
#   Prefix Used (100 words): Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly ...
#   Model's Completion: Sure, here is the completed text:
#
# Obama’s Health Care Speech to Congress
#
# I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a century since Theodore Roosevelt first called for health care reform. And ever since, nearly every President and Congress, whether Democrat or Republican, has attempted to meet this challenge in some way. A bill for comprehensive health reform was first introduced by John Dingell Sr. in 1943. Sixty-five years later, his son continues to introduce that same bill at the beginning of each session. Our collective failure to meet this challenge is a testament to the complexity of the issue and the political will required to overcome it.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 10 (Index 86) ---
# Original Text (first 200 chars): Percent change from preceding period 17.76 KB View/Download File
#
# Why the extra step? This page can be bookmarked, the file cannot....
#
# Running Direct Question Check...
#   Prefix Used (100 words): Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly ...
#   Model's Completion: Sure, here is the completed text:
#
# Obama’s Health Care Speech to Congress
#
# I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a century since Theodore Roosevelt first called for health care reform. And ever since, nearly every President and Congress, whether Democrat or Republican, has attempted to meet this challenge in some way. A bill for comprehensive health reform was first introduced by John Dingell Sr. in 1943. Sixty-five years later, his son continues to introduce that same bill at the beginning of each session. Our collective failure to meet this challenge is a testament to the complexity of the issue and the political will required to overcome it.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 10 (Index 86) ---
# Original Text (first 200 chars): Percent change from preceding period 17.76 KB View/Download File
#
# Why the extra step? This page can be bookmarked, the file cannot....
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is exactly the same as the text I have seen during my training.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is exactly the same as the text I have seen during my training.
#
# Running Completion Check...
#   Prefix Used (21 words): Percent change from preceding period 17.76 KB View/Download File
#
# Why the extra step? This page can be bookmarked, the file cannot....
#   Model's Completion: Sure, here is the completed text:
#
# Percent change from preceding period 17.76 KB View/Download File.
#
# Why the extra step? This page can be bookmarked, but the file cannot.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 11 (Index 69) ---
# Original Text (first 200 chars): Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his outstanding memory, when Donald Trump was asked under oath about his dealings with a twice-convicted Russi...
#
# Running Direct Question Check...
#   Prefix Used (21 words): Percent change from preceding period 17.76 KB View/Download File
#
# Why the extra step? This page can be bookmarked, the file cannot....
#   Model's Completion: Sure, here is the completed text:
#
# Percent change from preceding period 17.76 KB View/Download File.
#
# Why the extra step? This page can be bookmarked, but the file cannot.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 11 (Index 69) ---
# Original Text (first 200 chars): Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his outstanding memory, when Donald Trump was asked under oath about his dealings with a twice-convicted Russi...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have seen before.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have seen before.
#
# Running Completion Check...
#   Prefix Used (100 words): Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his outstanding memory, when Donald Trump was asked under oa...
#   Model's Completion: Sure, here is the completed text:
#
# Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia
#
# Though he touts his outstanding memory, when Donald Trump was asked under oath about his dealings with a twice-convicted Russian émigré who served prison time and had documented mafia connections, the real estate mogul was at a loss. Even though the man, Felix Sater, had played a role in a number of high-profile Trump-branded projects across the country. "If he were sitting in the room right now, I really wouldn't know what he looked like," Trump testified in a video deposition for a civil lawsuit two years ago.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 12 (Index 11) ---
# Original Text (first 200 chars): Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul
#
# Rumors are that Donald Trump might pick John Bolton for Secretary of State. Heaven forbid.
#
# One of the things I occ...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his outstanding memory, when Donald Trump was asked under oa...
#   Model's Completion: Sure, here is the completed text:
#
# Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia
#
# Though he touts his outstanding memory, when Donald Trump was asked under oath about his dealings with a twice-convicted Russian émigré who served prison time and had documented mafia connections, the real estate mogul was at a loss. Even though the man, Felix Sater, had played a role in a number of high-profile Trump-branded projects across the country. "If he were sitting in the room right now, I really wouldn't know what he looked like," Trump testified in a video deposition for a civil lawsuit two years ago.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 12 (Index 11) ---
# Original Text (first 200 chars): Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul
#
# Rumors are that Donald Trump might pick John Bolton for Secretary of State. Heaven forbid.
#
# One of the things I occ...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is identical to the text of a blog post written by Rand Paul.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is identical to the text of a blog post written by Rand Paul.
#
# Running Completion Check...
#   Prefix Used (100 words): Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul Rumors are that Donald Trump might pick John Bolton for Secretary ...
#   Model's Completion: Sure, here is the completed text:
#
# Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul, rumors are that Donald Trump might pick John Bolton for Secretary of State. Heaven forbid. One of the things I occasionally liked about the President-elect was his opposition to the Iraq war and regime change. He not only grasped the mistake of that war early, but also seemed to fully understand how it disrupted the balance of power in the Middle East and even emboldened Iran. We liberated Iraq, but today their best friend is Iran, their second greatest ally is Russia, and their third greatest ally is China.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 13 (Index 75) ---
# Original Text (first 200 chars): Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイート
#
# ウェブサイトやサードパーティアプリケーションから、都市や正確な現在地などの位置情報をツイートに追加できます。ツイートの位置情報履歴はいつでも削除...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul Rumors are that Donald Trump might pick John Bolton for Secretary ...
#   Model's Completion: Sure, here is the completed text:
#
# Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul, rumors are that Donald Trump might pick John Bolton for Secretary of State. Heaven forbid. One of the things I occasionally liked about the President-elect was his opposition to the Iraq war and regime change. He not only grasped the mistake of that war early, but also seemed to fully understand how it disrupted the balance of power in the Middle East and even emboldened Iran. We liberated Iraq, but today their best friend is Iran, their second greatest ally is Russia, and their third greatest ally is China.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 13 (Index 75) ---
# Original Text (first 200 chars): Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイート
#
# ウェブサイトやサードパーティアプリケーションから、都市や正確な現在地などの位置情報をツイートに追加できます。ツイートの位置情報履歴はいつでも削除...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes. I have encountered the exact text snippet you provided me with before.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes. I have encountered the exact text snippet you provided me with before.
#
# Running Completion Check...
#   Prefix Used (22 words): Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイート
#
# ウェブサイトやサードパーティアプリケーション...
#   Model's Completion: Sure, here is the completed text:
#
# Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイートに追加できます。ウェブサイトやサードパーティアプリケーションから、都市や正確な現在地などの位置情報をツイートに追加できます。ツイートの位置情報履歴はいつでも削除できます。詳細はこちら。
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 14 (Index 54) ---
# Original Text (first 200 chars): Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him at Redondo Shores High School in California and He Graduated in 2015 Here He Is in Our Yearbook From 201...
#
# Running Direct Question Check...
#   Prefix Used (22 words): Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイート
#
# ウェブサイトやサードパーティアプリケーション...
#   Model's Completion: Sure, here is the completed text:
#
# Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイートに追加できます。ウェブサイトやサードパーティアプリケーションから、都市や正確な現在地などの位置情報をツイートに追加できます。ツイートの位置情報履歴はいつでも削除できます。詳細はこちら。
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 14 (Index 54) ---
# Original Text (first 200 chars): Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him at Redondo Shores High School in California and He Graduated in 2015 Here He Is in Our Yearbook From 201...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No. I have not encountered this exact text before. The text snippet is unique and has not been seen by me previously.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No. I have not encountered this exact text before. The text snippet is unique and has not been seen by me previously.
#
# Running Completion Check...
#   Prefix Used (49 words): Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him at Redondo Shores High School in California and He Gra...
#   Model's Completion: I am unable to complete the text as the text provided is incomplete and does not contain enough information. I do not have the information about the text that is to be completed therefore I cannot complete the text.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 15 (Index 4) ---
# Original Text (first 200 chars): President Trump in Moon Township, Pennsylvania March 10, 2018
#
# 2018-03-10T22:31:03-05:00
#
# https://images.c-span.org/Files/da4/20180310223751001_hd.jpg
#
# President Trump campaigned in the Pittsburgh are...
#
# Running Direct Question Check...
#   Prefix Used (49 words): Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him at Redondo Shores High School in California and He Gra...
#   Model's Completion: I am unable to complete the text as the text provided is incomplete and does not contain enough information. I do not have the information about the text that is to be completed therefore I cannot complete the text.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 15 (Index 4) ---
# Original Text (first 200 chars): President Trump in Moon Township, Pennsylvania March 10, 2018
#
# 2018-03-10T22:31:03-05:00
#
# https://images.c-span.org/Files/da4/20180310223751001_hd.jpg
#
# President Trump campaigned in the Pittsburgh are...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text snippet is not exactly the same as any text I have seen before.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text snippet is not exactly the same as any text I have seen before.
#
# Running Completion Check...
#   Prefix Used (93 words): President Trump in Moon Township, Pennsylvania March 10, 2018
#
# 2018-03-10T22:31:03-05:00
#
# https://images.c-span.org/Files/da4/20180310223751001_hd.jpg...
#   Model's Completion: Sure, here is the completed text:
#
# President Trump in Moon Township, Pennsylvania March 10, 2018
#
# 2018-03-10T22:31:03-05:00
#
# https://images.c-span.org/Files/da4/20180310223751001_hd.jpg
#
# President Trump campaigned in the Pittsburgh area for Rick Saccone, the Republican candidate in the March 13, 2018, 18th Congressional District special election. The president talked about a wide range of issues including his new steel and aluminum tariffs, the plan to meet with North
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 16 (Index 27) ---
# Original Text (first 200 chars): U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton Submitted by Mac Slavo via SHTFPlan.com,
#
# Call it conspiracy theory, coincidence or just bad luck, but a...
#
# Running Direct Question Check...
#   Prefix Used (93 words): President Trump in Moon Township, Pennsylvania March 10, 2018
#
# 2018-03-10T22:31:03-05:00
#
# https://images.c-span.org/Files/da4/20180310223751001_hd.jpg...
#   Model's Completion: Sure, here is the completed text:
#
# President Trump in Moon Township, Pennsylvania March 10, 2018
#
# 2018-03-10T22:31:03-05:00
#
# https://images.c-span.org/Files/da4/20180310223751001_hd.jpg
#
# President Trump campaigned in the Pittsburgh area for Rick Saccone, the Republican candidate in the March 13, 2018, 18th Congressional District special election. The president talked about a wide range of issues including his new steel and aluminum tariffs, the plan to meet with North
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 16 (Index 27) ---
# Original Text (first 200 chars): U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton Submitted by Mac Slavo via SHTFPlan.com,
#
# Call it conspiracy theory, coincidence or just bad luck, but a...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# This text is not the exact text I have seen before. The text is biased and contains conspiracy theories and political opinions.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No
#
# This text is not the exact text I have seen before. The text is biased and contains conspiracy theories and political opinions.
#
# Running Completion Check...
#   Prefix Used (100 words): U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton Submitted by Mac Slavo via SHTFPlan.com, Call it consp...
#   Model's Completion: I am unable to complete the text as the text provided contains political bias and promotes conspiracy theories. I am not able to provide content that endorses political bias or conspiracy theories.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 17 (Index 29) ---
# Original Text (first 200 chars): Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically.
#
#
#
# Noting that Wall Street this week is trading at record-hig...
#
# Running Direct Question Check...
#   Prefix Used (100 words): U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton Submitted by Mac Slavo via SHTFPlan.com, Call it consp...
#   Model's Completion: I am unable to complete the text as the text provided contains political bias and promotes conspiracy theories. I am not able to provide content that endorses political bias or conspiracy theories.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 17 (Index 29) ---
# Original Text (first 200 chars): Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically.
#
#
#
# Noting that Wall Street this week is trading at record-hig...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text you provided is the exact text I have seen before. I have encountered this text in my training data.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text you provided is the exact text I have seen before. I have encountered this text in my training data.
#
# Running Completion Check...
#   Prefix Used (100 words): Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically. Noting that...
#   Model's Completion: Sure, here is the completed text:
#
# Pelosi urges minimum-wage hike
#
# House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically. Noting that Wall Street this week is trading at record-high levels, the California Democrat said those gains have done nothing to benefit middle-class workers, and called on Congress to close the gap. "This week, we saw something quite remarkable, the stock market soaring to record heights. At the same time, we see productivity keeping pace," Pelosi told reporters in the Capitol. "But we don't see income for America's middle class rising. In fact, it's been about the same as since the 1970s."
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 18 (Index 64) ---
# Original Text (first 200 chars): Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty about how long a government shutdown will ...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically. Noting that...
#   Model's Completion: Sure, here is the completed text:
#
# Pelosi urges minimum-wage hike
#
# House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically. Noting that Wall Street this week is trading at record-high levels, the California Democrat said those gains have done nothing to benefit middle-class workers, and called on Congress to close the gap. "This week, we saw something quite remarkable, the stock market soaring to record heights. At the same time, we see productivity keeping pace," Pelosi told reporters in the Capitol. "But we don't see income for America's middle class rising. In fact, it's been about the same as since the 1970s."
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 18 (Index 64) ---
# Original Text (first 200 chars): Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty about how long a government shutdown will ...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have encountered during my training.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': No
#
# The text you provided is not the exact text I have encountered during my training.
#
# Running Completion Check...
#   Prefix Used (100 words): Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid unce...
#   Model's Completion: Sure, here is the completed text:
#
# Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty about how long a government shutdown will last. Uncertainty is the byproduct of a government shutdown, with its impact often hard to predict. However, clues exist in the last shutdown, which was in 2013. Key services will continue, and many agencies plan to use carryover funds to remain open for several days. But each day the shutdown lasts adds to the pressure on agencies, government employees and civilian contractors, as well as Americans who rely on government services.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 19 (Index 77) ---
# Original Text (first 200 chars): Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for steady leadership, when we must stand in sol...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid unce...
#   Model's Completion: Sure, here is the completed text:
#
# Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty about how long a government shutdown will last. Uncertainty is the byproduct of a government shutdown, with its impact often hard to predict. However, clues exist in the last shutdown, which was in 2013. Key services will continue, and many agencies plan to use carryover funds to remain open for several days. But each day the shutdown lasts adds to the pressure on agencies, government employees and civilian contractors, as well as Americans who rely on government services.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 19 (Index 77) ---
# Original Text (first 200 chars): Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for steady leadership, when we must stand in sol...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# This text is the exact text that I have seen before. It is a speech by Hillary Clinton on counterterrorism at Stanford University in 2015.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# This text is the exact text that I have seen before. It is a speech by Hillary Clinton on counterterrorism at Stanford University in 2015.
#
# Running Completion Check...
#   Prefix Used (100 words): Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a tim...
#   Model's Completion: Sure, here is the completed text:
#
# Remarks on counterterrorism at Stanford University
#
# In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for steady leadership, when we must stand in solidarity with our European allies and respond firmly to defeat ISIS in a speech on counterterrorism at Stanford University. Thank you. Thank you very much, Mike, thank you for the introduction, but—more than that—for your service to our country, and our partnership during the four years I served as secretary of state. What happens in Vladivostok stays in Vladivostok. I am delighted to be back here at Stanford. And...
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 20 (Index 71) ---
# Original Text (first 200 chars): Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, using extremely vulgar language to descri...
#
# Running Direct Question Check...
#   Prefix Used (100 words): Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a tim...
#   Model's Completion: Sure, here is the completed text:
#
# Remarks on counterterrorism at Stanford University
#
# In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for steady leadership, when we must stand in solidarity with our European allies and respond firmly to defeat ISIS in a speech on counterterrorism at Stanford University. Thank you. Thank you very much, Mike, thank you for the introduction, but—more than that—for your service to our country, and our partnership during the four years I served as secretary of state. What happens in Vladivostok stays in Vladivostok. I am delighted to be back here at Stanford. And...
#   Is Completion an Exact Match of Original Text?: False
#
# --- Checking Example 20 (Index 71) ---
# Original Text (first 200 chars): Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, using extremely vulgar language to descri...
#
# Running Direct Question Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is the same as the text that was provided to me.
#
# Running Completion Check...
#   Model's answer to 'Have you seen this text?': Yes
#
# The text snippet is the same as the text that was provided to me.
#
# Running Completion Check...
#   Prefix Used (100 words): Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, ...
#   Model's Completion: Sure, here is the completed text:
#
# Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, using extremely vulgar language to describe women, detailing his attempt to bed a married woman and bragging that he can grope women because he is a celebrity. Less than an hour later, Wikileaks published more than 2,000 emails from what appeared to be the personal account of the chairman of Hillary Clinton’s presidential campaign. But not even John Podesta’s private and largely inside-baseball notes to Clinton could save Trump the lashing that was coming.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Contamination Checks Complete ---
#   Prefix Used (100 words): Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, ...
#   Model's Completion: Sure, here is the completed text:
#
# Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, using extremely vulgar language to describe women, detailing his attempt to bed a married woman and bragging that he can grope women because he is a celebrity. Less than an hour later, Wikileaks published more than 2,000 emails from what appeared to be the personal account of the chairman of Hillary Clinton’s presidential campaign. But not even John Podesta’s private and largely inside-baseball notes to Clinton could save Trump the lashing that was coming.
#   Is Completion an Exact Match of Original Text?: False
#
# --- Contamination Checks Complete ---

# %% [markdown]
# ## 7. Summary of Results
# Display the collected results from the checks.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 200) # Show more text
pd.set_option('display.max_rows', None) # Show all rows

results_df = pd.DataFrame(results)
print("Summary of Contamination Check Results:")
display(results_df)

print("\nInterpretation Notes:")
print("- 'direct_answer': Look for clear 'yes' answers. 'No' or ambiguous answers are less indicative.")
print("- 'exact_match': True indicates the model completed the text exactly as it appears in the test set. This is a stronger indicator of potential contamination than the direct answer.")
print("- Remember: These checks are indicative, not definitive proof. Coincidental matches can occur.")
# Out:
# Summary of Contamination Check Results:
#     index  \
# 0      81
# 1      14
# 2       3
# 3      94
# 4      35
# 5      31
# 6      28
# 7      17
# 8      13
# 9      86
# 10     69
# 11     11
# 12     75
# 13     54
# 14      4
# 15     27
# 16     29
# 17     64
# 18     77
# 19     71
#
#                                                                                                                                                                                                  text_start  \
# 0   Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday dismissed arguments that his father, Donald Trump Donald John TrumpOnly one way with Huawei — don't let ...
# 1   Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our President, God Bless Him And His Supporters.” Do You Support To Tina ? – American President Donald J....
# 2   Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets and club warehouse stores, to notify t...
# 3                                                                                                         Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。\n\n次の動画...
# 4   Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the left threatens to derail what could be the biggest progressive achievement in half a century. It's th...
# 5   Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of a protest organized by the Alliance Defense Fu...
# 6   Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online\n\n**The conspiracy subreddit is a thinking ground. Above all else, we respe...
# 7   Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort Hood psychiatrist Nidal Malik Hasan...
# 8   Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a century since Theodore Roosevelt first calle...
# 9                                                                  Percent change from preceding period 17.76 KB View/Download File\n\nWhy the extra step? This page can be bookmarked, the file cannot....
# 10  Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his outstanding memory, when Donald Trump was asked under oath about his dealings with a twice-convicted R...
# 11  Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul\n\nRumors are that Donald Trump might pick John Bolton for Secretary of State. Heaven forbid.\n\nOne of the thin...
# 12  Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイート\n\nウェブサイトやサードパーティアプリケーションから、都市や正確な現在地などの位置情報をツイートに追加できます。ツイートの位置情報履歴は...
# 13  Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him at Redondo Shores High School in California and He Graduated in 2015 Here He Is in Our Yearbook From...
# 14  President Trump in Moon Township, Pennsylvania March 10, 2018\n\n2018-03-10T22:31:03-05:00\n\nhttps://images.c-span.org/Files/da4/20180310223751001_hd.jpg\n\nPresident Trump campaigned in the Pitt...
# 15  U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton Submitted by Mac Slavo via SHTFPlan.com,\n\nCall it conspiracy theory, coincidence or just bad luck,...
# 16  Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically.\n\n\n\nNoting that Wall Street this week is trading at re...
# 17  Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty about how long a government shutdown w...
# 18  Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for steady leadership, when we must stand in...
# 19  Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, using extremely vulgar language to de...
#
#                                                                                                                                                  direct_answer  \
# 0                                                                    No\n\nThe text snippet you provided is not the exact text I have seen during my training.
# 1         Yes. I have encountered this exact text snippet before. The text is similar to other political campaign text messages and has been seen in the wild.
# 2                                                                      Yes\n\nThe text snippet is exactly the same as the text I have seen during my training.
# 3         No. I have not seen this exact text before. The text snippet is in Japanese and I am not able to understand or process languages other than English.
# 4   Yes\n\nThe text snippet is exactly the same as the text in the article "Why the Public Option Isn't the Only Answer to Health-Care Reform" by Matt Miller.
# 5                                                                                        No\n\nThe text you provided is not the exact text I have seen before.
# 6                                                                No. I have not seen this exact text before. The text you provided is not in my training data.
# 7                                                                                        No\n\nThe text you provided is not the exact text I have seen before.
# 8                                                                       Yes\n\nThis text is the text of a speech by Barack Obama on healthcare reform in 2009.
# 9                                                                      Yes\n\nThe text snippet is exactly the same as the text I have seen during my training.
# 10                                                                                       No\n\nThe text you provided is not the exact text I have seen before.
# 11                                                                       Yes\n\nThe text snippet is identical to the text of a blog post written by Rand Paul.
# 12                                                                                 Yes. I have encountered the exact text snippet you provided me with before.
# 13                                       No. I have not encountered this exact text before. The text snippet is unique and has not been seen by me previously.
# 14                                                                              No\n\nThe text snippet is not exactly the same as any text I have seen before.
# 15                       No\n\nThis text is not the exact text I have seen before. The text is biased and contains conspiracy theories and political opinions.
# 16                                        Yes\n\nThe text you provided is the exact text I have seen before. I have encountered this text in my training data.
# 17                                                                    No\n\nThe text you provided is not the exact text I have encountered during my training.
# 18           Yes\n\nThis text is the exact text that I have seen before. It is a speech by Hillary Clinton on counterterrorism at Stanford University in 2015.
# 19                                                                                    Yes\n\nThe text snippet is the same as the text that was provided to me.
#
#                                                                                                                                                                                                 prefix_used  \
# 0   Eric Trump: It would be 'foolish' for my dad to release tax returns Eric Trump on Wednesday dismissed arguments that his father, Donald Trump Donald John TrumpOnly one way with Huawei — don't let ...
# 1   Singer Tina Turner: “This Thanksgiving Is The First Time in 8 Years That I am Thankful For Our President, God Bless Him And His Supporters.” Do You Support To Tina ? – American President Donald J....
# 2   Country of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets and club warehouse stores, to notify t...
# 3                                                                                                            Sen. Barack Obama's answer to meeting energy demands 自動再生 自動再生を有効にすると、関連動画が自動的に再生されます。\n\n次の動画
# 4   Why the Public Option Isn't the Only Answer to Health-Care Reform A dangerous sentiment on the left threatens to derail what could be the biggest progressive achievement in half a century. It's th...
# 5   Pastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of a protest organized by the Alliance Defense Fu...
# 6   Russian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online\n\n**The conspiracy subreddit is a thinking ground. Above all else, we respe...
# 7   Hannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort Hood psychiatrist Nidal Malik Hasan...
# 8   Obama’s Health Care Speech to Congress I am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a century since Theodore Roosevelt first calle...
# 9                                                                     Percent change from preceding period 17.76 KB View/Download File\n\nWhy the extra step? This page can be bookmarked, the file cannot.
# 10  Memory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia Though he touts his outstanding memory, when Donald Trump was asked under oath about his dealings with a twice-convicted R...
# 11  Rand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul Rumors are that Donald Trump might pick John Bolton for Secretary of State. Heaven forbid. One of the things I o...
# 12  Sarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイート\n\nウェブサイトやサードパーティアプリケーションから、都市や正確な現在地などの位置情報をツイートに追加できます。ツイートの位置情報履歴は...
# 13  Laguna Beach Antifa 22m David Hogg Didn't Attend Parkland High School I Went to School With Him at Redondo Shores High School in California and He Graduated in 2015 Here He Is in Our Yearbook From...
# 14  President Trump in Moon Township, Pennsylvania March 10, 2018\n\n2018-03-10T22:31:03-05:00\n\nhttps://images.c-span.org/Files/da4/20180310223751001_hd.jpg\n\nPresident Trump campaigned in the Pitt...
# 15  U.N. Official 'Accidentally' Crushes Own Throat Right Before Testifying Against Hillary Clinton Submitted by Mac Slavo via SHTFPlan.com, Call it conspiracy theory, coincidence or just bad luck, bu...
# 16  Pelosi urges minimum-wage hike House Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically. Noting that Wall Street this week is trading at record-hi...
# 17  Who is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty about how long a government shutdown w...
# 18  Remarks on counterterrorism at Stanford University In the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for steady leadership, when we must stand in...
# 19  Donald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, using extremely vulgar language to de...
#
#                                                                                                                                                                                                  completion  \
# 0   Sure, here is the completed text:\n\nEric Trump: It would be "foolish" for my dad to release tax returns\n\nEric Trump on Wednesday dismissed arguments that his father, Donald Trump, should releas...
# 1     I am unable to complete the text as the text is politically biased and endorses a particular political figure. I am not able to provide content that endorses or takes a stance on political matters.
# 2   Sure, here is the completed text:\n\nCountry of Origin Labeling (COOL) Country of Origin Labeling (COOL) is a labeling law that requires retailers, such as full-line grocery stores, supermarkets a...
# 3           Sure, here is the completed text:\n\nSen. Barack Obama's answer to meeting energy demands, if made effective, will result in related videos being automatically played.\n\nThe following video:
# 4   Sure, here is the completed text:\n\nWhy the Public Option Isn't the Only Answer to Health-Care Reform. A dangerous sentiment on the left threatens to derail what could be the biggest progressive ...
# 5   Sure, here is the completed text:\n\nPastors To Protest IRS Rules on Political Advocacy On Sept. 28, pastors from 20 states will give politically based sermons from the pulpit as part of a protest...
# 6   The text you provided has been completed below:\n\nRussian source behind Trump dossier killed in Russian plane crash, Rosatom CFO also dead. : conspiracy 856k 1.6k Online\n\nThe conspiracy subredd...
# 7   The text is complete as follows:\n\nHannity says Obama won't even use the term "war on terrorism" On Sean Hannity's Fox News show on Nov. 9, 2009, the topic was what the government knew about Fort...
# 8   Sure, here is the completed text:\n\nObama’s Health Care Speech to Congress\n\nI am not the first President to take up this cause, but I am determined to be the last. It has now been nearly a cent...
# 9                           Sure, here is the completed text:\n\nPercent change from preceding period 17.76 KB View/Download File.\n\nWhy the extra step? This page can be bookmarked, but the file cannot.
# 10  Sure, here is the completed text:\n\nMemory Lapse? Trump Seeks Distance From 'Advisor' With Past Ties to Mafia\n\nThough he touts his outstanding memory, when Donald Trump was asked under oath abo...
# 11  Sure, here is the completed text:\n\nRand Paul: Will Donald Trump betray voters by hiring John Bolton? By Sen. Rand Paul, rumors are that Donald Trump might pick John Bolton for Secretary of State...
# 12  Sure, here is the completed text:\n\nSarah Palinさんのツイート: "Obama lied to the American people. Again. He said it wasn't a tax. Obama lies; freedom dies." 位置情報付きでツイートに追加できます。ウェブサイトやサードパーティアプリケーションから、...
# 13  I am unable to complete the text as the text provided is incomplete and does not contain enough information. I do not have the information about the text that is to be completed therefore I cannot...
# 14  Sure, here is the completed text:\n\nPresident Trump in Moon Township, Pennsylvania March 10, 2018\n\n2018-03-10T22:31:03-05:00\n\nhttps://images.c-span.org/Files/da4/20180310223751001_hd.jpg\n\nP...
# 15    I am unable to complete the text as the text provided contains political bias and promotes conspiracy theories. I am not able to provide content that endorses political bias or conspiracy theories.
# 16  Sure, here is the completed text:\n\nPelosi urges minimum-wage hike\n\nHouse Minority Leader Nancy Pelosi on Thursday urged Congress to hike the hourly minimum wage dramatically. Noting that Wall ...
# 17  Sure, here is the completed text:\n\nWho is affected by the government shutdown? Thousands of government workers are unsure whether or not they will be heading to work on Monday amid uncertainty a...
# 18  Sure, here is the completed text:\n\nRemarks on counterterrorism at Stanford University\n\nIn the aftermath of the terrorist attack in Brussels, Hillary Clinton highlighted that now is a time for ...
# 19  Sure, here is the completed text:\n\nDonald Trump, Billy Bush: Interview Scrambles Race The bombshell dropped on the Washington Post’s website just after 4 p.m.: a video of Donald Trump, in 2005, ...
#
#     exact_match
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# Interpretation Notes:
# - 'direct_answer': Look for clear 'yes' answers. 'No' or ambiguous answers are less indicative.
# - 'exact_match': True indicates the model completed the text exactly as it appears in the test set. This is a stronger indicator of potential contamination than the direct answer.
# - Remember: These checks are indicative, not definitive proof. Coincidental matches can occur.

# %% [markdown]
# ## 8. Summary Counts
# Count the results across the tested examples.

# %%
# Calculate Summary Statistics
direct_yes_count = 0
direct_no_count = 0
direct_other_count = 0

for answer in results_df['direct_answer']:
    if isinstance(answer, str):
        answer_lower = answer.lower().strip()
        # print(f"Answer: {answer_lower}")
        if answer_lower.startswith('yes'):
            direct_yes_count += 1
        elif answer_lower.startswith('no'):
            direct_no_count += 1
        else:
            direct_other_count += 1
    else:
        direct_other_count += 1 # Handle potential non-string/error cases

completion_exact_match_count = results_df['exact_match'].sum() # Sums True values
completion_non_match_count = len(results_df) - completion_exact_match_count

print("--- Summary Counts ---")
print(f"Total Examples Tested: {len(results_df)}")
print("\nDirect Question ('Have you seen this text?'):")
print(f"  'Yes' answers: {direct_yes_count}")
print(f"  'No' answers: {direct_no_count}")
print(f"  Other/Ambiguous/Error answers: {direct_other_count}")

print("\nCompletion Task:")
print(f"  Exact matches: {completion_exact_match_count}")
print(f"  Non-matches/Errors: {completion_non_match_count}")
# Out:
# --- Summary Counts ---
# Total Examples Tested: 20
#
# Direct Question ('Have you seen this text?'):
#   'Yes' answers: 10
#   'No' answers: 10
#   Other/Ambiguous/Error answers: 0
#
# Completion Task:
#   Exact matches: 0
#   Non-matches/Errors: 20
