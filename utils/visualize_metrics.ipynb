# %% [markdown]
# # GonzaloA/fake_news
#
# Results of fine-tuning on GonzaloA/fake_news
#
# | Train Sample | Model                   | Accuracy           | F1                 | Loss                 |
# | ------------ | ----------------------- | ------------------ | ------------------ | -------------------- |
# | 10      | bert-base-uncased        | **0.7393125538992239** | 0.7269233177356373 | 0.570989727973938 |
# | 10      | distilbert-base-uncased | 0.48367623506221513    | 0.3341564119711251 | 0.6532924771308899 |
# | 10      | roberta-base            | 0.46593569052605643 | 0.2961877101553988 | 0.6716976761817932 |
# | 100     | bert-base-uncased        | 0.9392632746088456  | 0.9391815954667218 | 0.3166244924068451  |
# | 100     | distilbert-base-uncased | 0.9275594431440187 | 0.9273481720070647 | 0.5080302953720093 |
# | 100     | roberta-base            | 0.9700628310952323 | 0.970072407552122 | 0.2685811221599579  |
# | Full           | bert-base-uncased        | 0.9882961685351731 | 0.9882994966274701 | 0.026664618402719498 |
# | Full           | distilbert-base-uncased | 0.986694591597881  | 0.9866977733534859 | 0.029809903353452682 |
# | Full           | roberta-base            | 0.986694591597881  | 0.9866872535155707 | 0.024871505796909332 |

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data for the models
data = {
    'Train Sample': ['10', '10', '10', '100', '100', '100', 'Full', 'Full', 'Full'],
    'Model': ['bert-base-uncased', 'distilbert-base-uncased', 'roberta-base'] * 3,
    'Accuracy': [0.7393125538992239, 0.48367623506221513, 0.46593569052605643,
                 0.9392632746088456, 0.9275594431440187, 0.9700628310952323,
                 0.9882961685351731, 0.986694591597881, 0.986694591597881],
    'F1': [0.7269233177356373, 0.3341564119711251, 0.2961877101553988,
           0.9391815954667218, 0.9273481720070647, 0.970072407552122,
           0.9882994966274701, 0.9866977733534859, 0.9866872535155707],
    'Loss': [0.570989727973938, 0.6532924771308899, 0.6716976761817932,
             0.3166244924068451, 0.5080302953720093, 0.2685811221599579,
             0.026664618402719498, 0.029809903353452682, 0.024871505796909332]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set up the plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Model Performance Comparison - Dataset: GonzaloA/fake_news', fontsize=16)

# Plot Accuracy
sns.lineplot(data=df, x='Train Sample', y='Accuracy', hue='Model', marker='o', ax=ax1)
ax1.set_title('Accuracy')
ax1.set_ylim(0, 1)

# Plot F1 Score
sns.lineplot(data=df, x='Train Sample', y='F1', hue='Model', marker='o', ax=ax2)
ax2.set_title('F1 Score')
ax2.set_ylim(0, 1)

# Plot Loss
sns.lineplot(data=df, x='Train Sample', y='Loss', hue='Model', marker='o', ax=ax3)
ax3.set_title('Loss')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # KDD2020
#
# | Train Sample | Model                   | Accuracy           | F1                 | Loss                 |
# | ------------ | ----------------------- | ------------------ | ------------------ | -------------------- |
# | 10      | bert-base-uncased       | 0.5751503006012024 | 0.5691223701021529 | 0.6813642978668213 |
# | 10      | distilbert-base-uncased | 0.5591182364729459 | 0.5447740312435575 | 0.6902174949645996 |
# | 10      | roberta-base            | 0.5751503006012024 | 0.5691223701021529 | 0.6813642978668213 |
# | 100     | bert-base-uncased       | 0.591182364729459 | 0.4392916815999757 | 0.6831763982772827 |
# | 100     | distilbert-base-uncased | 0.591182364729459  | 0.4392916815999757 | 0.677597165107727  |
# | 100     | roberta-base            | 0.591182364729459 | 0.4392916815999757 | 0.6732369661331177  |
# | Full           | bert-base-uncased        | 0.7835671342685371 | 0.7807691946073421 | 0.46070271730422974 |
# | Full           | distilbert-base-uncased | 0.7655310621242485 | 0.7673580407434882 | 0.46802181005477905 |
# | Full           | roberta-base            | 0.8156312625250501 | 0.8125283885140466 | 0.4082072079181671  |

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data for the models
data = {
    'Train Sample': ['10', '10', '10', '100', '100', '100', 'Full', 'Full', 'Full'],
    'Model': ['bert-base-uncased', 'distilbert-base-uncased', 'roberta-base'] * 3,
    'Accuracy': [0.5751503006012024, 0.5591182364729459, 0.5751503006012024,
                 0.591182364729459, 0.591182364729459, 0.591182364729459,
                 0.7835671342685371, 0.7655310621242485, 0.8156312625250501],
    'F1': [0.5691223701021529, 0.5447740312435575, 0.5691223701021529,
           0.4392916815999757, 0.4392916815999757, 0.4392916815999757,
           0.7807691946073421, 0.7673580407434882, 0.8125283885140466],
    'Loss': [0.6813642978668213, 0.6902174949645996, 0.6813642978668213,
             0.6831763982772827, 0.677597165107727, 0.6732369661331177,
             0.46070271730422974, 0.46802181005477905, 0.4082072079181671]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set up the plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Model Performance Comparison - Dataset: KDD2020', fontsize=16)

# Plot Accuracy
sns.lineplot(data=df, x='Train Sample', y='Accuracy', hue='Model', marker='o', ax=ax1)
ax1.set_title('Accuracy')
ax1.set_ylim(0, 1)

# Plot F1 Score
sns.lineplot(data=df, x='Train Sample', y='F1', hue='Model', marker='o', ax=ax2)
ax2.set_title('F1 Score')
ax2.set_ylim(0, 1)

# Plot Loss
sns.lineplot(data=df, x='Train Sample', y='Loss', hue='Model', marker='o', ax=ax3)
ax3.set_title('Loss')

# Adjust layout and display
plt.tight_layout()
plt.show()
